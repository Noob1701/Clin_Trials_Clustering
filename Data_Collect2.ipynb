# %% [markdown]
# <a href="https://colab.research.google.com/github/Noob1701/Clin_Trials_Clustering/blob/main/Data_Collect2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
import pandas as pd
import requests
import csv

# %%
# Initial URL for the first API call
base_url = "https://clinicaltrials.gov/api/v2/studies"

# Initialize an empty list to store the data
data_list = []
params = {
}

# %%
def write_to_csv(data_list, output_file):
    with open(output_file, 'a', newline='', encoding='utf-8') as f:
        headers = list(data_list[0].keys())
        writer = csv.DictWriter(f, fieldnames=headers)
        # Write headers only if file is empty
        if f.tell() == 0:
            writer.writeheader()

        for data in data_list:
            writer.writerow(data)

# %%
# Loop until there is no nextPageToken
while True:
    # Print the current URL (for debugging purposes)
    # print("Fetching data from:", base_url + '?' + '&'.join([f"{k}={v}" for k, v in params.items()]))

    # Send a GET request to the API
    response = requests.get(base_url, params=params)

    # Check if the request was successful
    if response.status_code == 200:
        data = response.json()  # Parse JSON response
        studies = data.get('studies', [])  # Extract the list of studies

        # Loop through each study and extract specific information
        for study in studies:
            # Safely access nested keys
                responsibleParty = study['protocolSection']['sponsorCollaboratorsModule'].get('responsibleParty', {}).get('type', 'Unknown')
                orgFullName = study['protocolSection']['identificationModule'].get('organization', {}).get('fullName', 'Unknown')
                orgClass = study['protocolSection']['identificationModule'].get('organization',{}).get('class', 'Unknown')
                overallStatus = study['protocolSection']['statusModule'].get('overallStatus', 'Unknown')

                startDate = study['protocolSection']['statusModule'].get('startDateStruct', {}).get('date', 'Unknown')
                if 'conditionsModule' in study['protocolSection']:
                  conditions = ', '.join(study['protocolSection']['conditionsModule'].get('conditions', ['Unknown']))
                else:
                  conditions = 'No conditions listed'
                briefTitle = study['protocolSection']['identificationModule'].get('briefTitle', 'Unknown')
                fullTitle = study['protocolSection']['identificationModule'].get('officialTitle', 'Unknown')
            # Extract interventions safely
                interventions_list = study['protocolSection'].get('armsInterventionsModule', {}).get('interventions', [])
                interventions = ', '.join([intervention.get('name', 'Unknown') for intervention in interventions_list]) if interventions_list else "Unknown"
                interventionDesc_list = study['protocolSection'].get('armsInterventionsModule', {}).get('interventions',[])
                interventionDesc = ', '.join([interventionDesc.get('description', 'Unknown') for interventionDesc in interventionDesc_list]) if interventionDesc_list else "Unknown"

            # Extract dates and phases
                if 'designModule' in study['protocolSection']:
                  studyType = study['protocolSection']['designModule'].get('studyType', 'Unknown')
                else:
                  studyType = 'Unknown'
                if 'designModule' in study['protocolSection']:
                  phases = ', '.join(study['protocolSection']['designModule'].get('phases', ['Unknown']))
                else:
                  phases = 'No phases listed'
                outcome_list = study.get('protocolSection', {}).get('outcomesModule', {}).get('primaryOutcomes', [])
                if outcome_list:
                  outcomes = ' '.join([outcome.get('measure', 'Unknown') for outcome in outcome_list])
                else:
                  outcomes = "Unknown"
                standardAge_list = study['protocolSection'].get('eligibilityModule', {}).get('stdAges',[])
                standardAge = ' '.join(standardAge_list)
                if 'designModule' in study['protocolSection']:
                  if 'designInfo' in study['protocolSection']['designModule']:
                    primaryPurpose = study['protocolSection']['designModule']['designInfo'].get('primaryPurpose', 'Unknown')
                  else:
                    primaryPurpose = 'Unknown'
                else:
                    primaryPurpose = 'Unknown'
                completion_date_list = startDate = study['protocolSection']['statusModule'].get('primaryCompletionDateStruct', {}).get('date', 'Unknown')
            # Append the data to the list as a dictionary
                data_list.append({
                    "Organization Full Name": orgFullName,
                    "Organization Class": orgClass,
                    "Responsible Party": responsibleParty,
                    "Brief Title": briefTitle,
                    "Full Title": fullTitle,
                    "Overall Status": overallStatus,
                    "Start Date": startDate,
                    "Standard Age": standardAge,
                    "Conditions": conditions,
                    "Primary Purpose": primaryPurpose,
                    "Interventions": interventions,
                    "Intervention Description": interventionDesc,
                    "Study Type": studyType,
                    "Phases": phases,
                    "Outcome Measure": outcomes,
                    "Completion Date": completion_date_list
                })

        # Check for nextPageToken and update the params or break the loop
        nextPageToken = data.get('nextPageToken')
        if nextPageToken:
            params['pageToken'] = nextPageToken  # Set the pageToken for the next request
        else:
            break  # Exit the loop if no nextPageToken is present
        if len(data_list) >= 1000:
            write_to_csv(data_list, 'clin_trials.csv')
            data_list = []  # Clear the data list after writing
    else:
        print("Failed to fetch data. Status code:", response.status_code)
        break

# %%
clin_trials = pd.read_csv('clin_trials.csv')

# %%
clin_trials.head(1)
# Out:
#         Organization Full Name Organization Class Responsible Party  \
# 0  University Hospital, Angers          OTHER_GOV           SPONSOR
#
#                                          Brief Title  \
# 0  Reproducibility of Ankle Brachial Index After ...
#
#                                           Full Title Overall Status  \
# 0  Reproducibility of the Ankle-Brachial Index Me...      COMPLETED
#
#   Start Date Standard Age       Conditions Primary Purpose Interventions  \
# 0    2014-04        ADULT  Normal Subjects         Unknown       Unknown
#
#   Intervention Description     Study Type   Phases  \
# 0                  Unknown  OBSERVATIONAL  Unknown
#
#                                      Outcome Measure Completion Date
# 0  Test-retest difference in ankle to brachial pr...         2014-04

# %%
clin_trials_wd = clin_trials[clin_trials['Completion Date'] != 'Unknown']

# %%
clin_trials_wd = clin_trials_wd[clin_trials_wd['Responsible Party'] == 'SPONSOR']

# %%
clin_trials_wd = clin_trials_wd[clin_trials_wd['Organization Class'] == 'INDUSTRY']

# %%
clin_trials_wd = clin_trials_wd[(clin_trials_wd['Completion Date'] < '2024-07-05') & (clin_trials_wd['Completion Date'] > '2022-01-01')]

# %%
clin_trials_wd = clin_trials_wd[clin_trials_wd['Phases'] == 'PHASE3']

# %%
column_to_move = 'Completion Date'
cols = [column_to_move] + [col for col in clin_trials_wd.columns if col != column_to_move]
clin_trials_wd = clin_trials_wd[cols]

# %%
clin_trials_wd.head(20)
# Out:
#      Completion Date                     Organization Full Name  \
# 66        2022-05-20  Shanghai Institute Of Biological Products
# 196       2023-11-15        Mikrobiomik Healthcare Company S.L.
# 745       2024-04-11                Agios Pharmaceuticals, Inc.
# 836       2023-06-23                        EuBiologics Co.,Ltd
# 998       2023-12-31             Supernus Pharmaceuticals, Inc.
# 1192      2023-07-26                       Bristol-Myers Squibb
# 1460         2023-07                               Galderma R&D
# 1522      2023-05-30                                   Medy-Tox
# 1650      2024-06-30                       RDC Clinical Pty Ltd
# 2037      2022-06-10                                      Ipsen
# 2062      2023-12-30                  Hamad Medical Corporation
# 2063      2022-11-17                    Merck Sharp & Dohme LLC
# 2093         2022-12                             Cell>Point LLC
# 2150      2023-04-13            Daewon Pharmaceutical Co., Ltd.
# 2409      2022-03-30                               Galderma R&D
# 2796      2023-03-30                     CanSino Biologics Inc.
# 2856      2022-08-30                        Quantum Genomics SA
# 2989      2023-08-24                                     Pfizer
# 3445      2022-08-26                                   Allergan
# 3772      2023-04-27                 Aimmune Therapeutics, Inc.
#
#      Organization Class Responsible Party  \
# 66             INDUSTRY           SPONSOR
# 196            INDUSTRY           SPONSOR
# 745            INDUSTRY           SPONSOR
# 836            INDUSTRY           SPONSOR
# 998            INDUSTRY           SPONSOR
# 1192           INDUSTRY           SPONSOR
# 1460           INDUSTRY           SPONSOR
# 1522           INDUSTRY           SPONSOR
# 1650           INDUSTRY           SPONSOR
# 2037           INDUSTRY           SPONSOR
# 2062           INDUSTRY           SPONSOR
# 2063           INDUSTRY           SPONSOR
# 2093           INDUSTRY           SPONSOR
# 2150           INDUSTRY           SPONSOR
# 2409           INDUSTRY           SPONSOR
# 2796           INDUSTRY           SPONSOR
# 2856           INDUSTRY           SPONSOR
# 2989           INDUSTRY           SPONSOR
# 3445           INDUSTRY           SPONSOR
# 3772           INDUSTRY           SPONSOR
#
#                                             Brief Title  \
# 66    A Study Comparing SIBP-02 and Rituximab Combin...
# 196   Primary or Recurrent Clostridioides Difficile ...
# 745   A Study Evaluating the Efficacy and Safety of ...
# 836   A Phase III Study of COVID-19 Vaccine EuCorVac...
# 998   Efficacy and Safety Study of MYOBLOC® in the T...
# 1192  A Study of Neoadjuvant Chemotherapy Plus Nivol...
# 1460  Efficacy and Safety of Nemolizumab in Subjects...
# 1522  Long-term Extension Study to Evaluate MBA-P01 ...
# 1650  Effect of Testofen on Erectile Function in an ...
# 2037  Study to Assess the Efficacy and Safety of Lan...
# 2062  Nebulized Lidocaine and Intranasal Midazolam f...
# 2063  Study of Doravirine/Islatravir (DOR/ISL 100 mg...
# 2093  A Phase 3 Study of 99mTC-EC-DG SPECT/CT Versus...
# 2150  Clinical Trial to Evaluate the Efficacy and Sa...
# 2409  A Study to Assess the Efficacy and Safety of N...
# 2796  A Study to Evaluate the Safety and Immunogenic...
# 2856     Firibastat in Treatment-resistant Hypertension
# 2989  Study to Evaluate the Effect of GBT440 on TCD ...
# 3445        JUVÉDERM VOLUX® for Chin Retrusion in China
# 3772  Longer-term Study of AR101 in Subjects Who Par...
#
#                                              Full Title  \
# 66    A Phase III, Multicenter, Randomized, Double-b...
# 196   A Randomised, Controlled, Open-label Phase III...
# 745   A Phase 3, Double-Blind, Randomized, Placebo-C...
# 836   A Phase III, Randomized, Observer-blind, Activ...
# 998   A Phase 3 Multicenter, Randomized, Double-Blin...
# 1192  A Phase 3, Randomized, Double-blind Study of N...
# 1460  A Randomized, Double-Blind, Placebo-Controlled...
# 1522  Open-label, Single Group, Multi-center, Repeat...
# 1650  Effect of Testofen on Erectile Function in an ...
# 2037  A Phase 3, Single-arm, Open-label, Multicentre...
# 2062  Nebulized Lidocaine and Intranasal Midazolam f...
# 2063  A Phase 3 Randomized, Active-Controlled, Doubl...
# 2093  A Multicenter Phase 3 Study Comparing the Diag...
# 2150  A Randomized, Double Blind, Parallel, Multi-ce...
# 2409  A Randomized, Double-Blind, Placebo-Controlled...
# 2796  A Multicenter, Randomized, and Observer-blind ...
# 2856  A Phase 3, Double-blind, Placebo-controlled, E...
# 2989  A Phase 3, Randomized, Double-Blind, Placebo-C...
# 3445  A Randomized, Multicenter, "No-Treatment" Cont...
# 3772  A Multicenter, Open-Label, Longer-Term Study o...
#
#              Overall Status  Start Date       Standard Age  \
# 66                COMPLETED  2022-05-20  ADULT OLDER_ADULT
# 196               COMPLETED  2023-11-15  ADULT OLDER_ADULT
# 745   ACTIVE_NOT_RECRUITING  2024-04-11  ADULT OLDER_ADULT
# 836               COMPLETED  2023-06-23  ADULT OLDER_ADULT
# 998      NOT_YET_RECRUITING  2023-12-31              CHILD
# 1192  ACTIVE_NOT_RECRUITING  2023-07-26  ADULT OLDER_ADULT
# 1460              WITHDRAWN     2023-07  ADULT OLDER_ADULT
# 1522              COMPLETED  2023-05-30  ADULT OLDER_ADULT
# 1650             RECRUITING  2024-06-30  ADULT OLDER_ADULT
# 2037              COMPLETED  2022-06-10  ADULT OLDER_ADULT
# 2062                UNKNOWN  2023-12-30              CHILD
# 2063  ACTIVE_NOT_RECRUITING  2022-11-17  ADULT OLDER_ADULT
# 2093                UNKNOWN     2022-12  ADULT OLDER_ADULT
# 2150              COMPLETED  2023-04-13  ADULT OLDER_ADULT
# 2409              COMPLETED  2022-03-30  ADULT OLDER_ADULT
# 2796              WITHDRAWN  2023-03-30  ADULT OLDER_ADULT
# 2856              COMPLETED  2022-08-30  ADULT OLDER_ADULT
# 2989  ACTIVE_NOT_RECRUITING  2023-08-24              CHILD
# 3445              COMPLETED  2022-08-26  ADULT OLDER_ADULT
# 3772              COMPLETED  2023-04-27        CHILD ADULT
#
#                                              Conditions Primary Purpose  \
# 66                        Diffuse Large B-Cell Lymphoma       TREATMENT
# 196   Recurrent Clostridium Difficile Infection, Pri...       TREATMENT
# 745   Transfusion-dependent Alpha-Thalassemia, Trans...       TREATMENT
# 836                                            COVID-19      PREVENTION
# 998                                          Sialorrhea       TREATMENT
# 1192                     Carcinoma, Non-Small-Cell Lung       TREATMENT
# 1460               Moderate-to-severe Atopic Dermatitis       TREATMENT
# 1522                              Glabellar Frown Lines       TREATMENT
# 1650                               Erectile Dysfunction       TREATMENT
# 2037        Gastroenteropancreatic Neuroendocrine Tumor       TREATMENT
# 2062                Procedural Anxiety, Procedural Pain       TREATMENT
# 2063                                    HIV-1 Infection       TREATMENT
# 2093                                        Lung Cancer      DIAGNOSTIC
# 2150                 Hypercholesterolemia, Dyslipidemia       TREATMENT
# 2409                                  Prurigo Nodularis       TREATMENT
# 2796                                           COVID-19      PREVENTION
# 2856                                       Hypertension       TREATMENT
# 2989                                Sickle Cell Disease       TREATMENT
# 3445                                     Chin Retrusion       TREATMENT
# 3772                                     Peanut Allergy       TREATMENT
#
#                                           Interventions  \
# 66                                   SIBP-02, Rituximab
# 196                                    MBK-01, Dificlir
# 745               Placebo Matching Mitapivat, Mitapivat
# 836                        EuCorVac-19, ChAdOx1 nCoV-19
# 998        MYOBLOC Low Dose, MYOBLOC High Dose, Placebo
# 1192  Nivolumab, Carboplatin, Cisplatin, Paclitaxel,...
# 1460                       Nemolizumab, CD14152 placebo
# 1522                                            MBA-P01
# 1650  Testofen 300mg, Testofen 600mg, Placebo compar...
# 2037                                 Lanreotide autogel
# 2062  Nebulized Lidocaine, Intranasal Midazolam, Pla...
# 2063  DOR/ISL, BIC/FTC/TAF, Placebo to BIC/FTC/TAF, ...
# 2093  (99m Tc) ECDG (Ethylenedicysteine-Deoxyglucose...
# 2150  Ezetimibe/Atorvastatin 10/5 mg, Atorvastatin 5...
# 2409                               Nemolizumab, Placebo
# 2796  Bivalent Recombinant COVID-19 Vaccine (Adenovi...
# 2856                                Firibastat, Placebo
# 2989                                 Voxelotor, Placebo
# 3445                                    JUVÉDERM VOLUX®
# 3772                                              AR101
#
#                                Intervention Description      Study Type  \
# 66           Injection，100mg/10ml, Injection，100mg/10ml  INTERVENTIONAL
# 196   A single dose of 4 capsules of MBK-01 (heterol...  INTERVENTIONAL
# 745                                    Tablets, Tablets  INTERVENTIONAL
# 836                  COVID-19 vaccine, COVID-19 vaccine  INTERVENTIONAL
# 998   Weight-based dose; 5.0 units/kg for submandibu...  INTERVENTIONAL
# 1192  Specified dose on specified days, Specified do...  INTERVENTIONAL
# 1460  Participants will receive loading dose of 60 m...  INTERVENTIONAL
# 1522  MBA-P01 will be injected into the Glabellar line.  INTERVENTIONAL
# 1650  Testofen in capsule form - To be taken as a 30...  INTERVENTIONAL
# 2037  Administered as deep subcutaneous (SC) injections  INTERVENTIONAL
# 2062  Nebulized Lidocaine for Reducing Pain of Nasog...  INTERVENTIONAL
# 2063  100 mg DOR/0.75 mg ISL FDC tablet taken once d...  INTERVENTIONAL
# 2093  One injection of Technetium-99m Ethylenedicyst...  INTERVENTIONAL
# 2150  DW1125, DW1125A, DW1125E, DW1125A-1, Ezetimibe...  INTERVENTIONAL
# 2409  Participants will receive either 30 mg or 60 m...  INTERVENTIONAL
# 2796  Subjects who have completed the primary mRNA v...  INTERVENTIONAL
# 2856  Oral administration 2×250 mg capsules bid, Ora...  INTERVENTIONAL
# 2989  Participants are randomized 1:1 to receive vox...  INTERVENTIONAL
# 3445                     JUVÉDERM VOLUX® injectable gel  INTERVENTIONAL
# 3772                                              AR101  INTERVENTIONAL
#
#       Phases                                    Outcome Measure
# 66    PHASE3                        Overall Response Rate (ORR)
# 196   PHASE3  Global Absence of diarrhea: Number of episodes...
# 745   PHASE3  Percentage of Participants With Transfusion Re...
# 836   PHASE3  The proportion of GMT of neutralizing antibody...
# 998   PHASE3  Effect of MYOBLOC on Unstimulated Saliva Flow ...
# 1192  PHASE3  Event-Free Survival (EFS) as Assessed by Blind...
# 1460  PHASE3  Proportion of Participants with Eczema Area an...
# 1522  PHASE3  Incidence rate of treatment-emergent adverse e...
# 1650  PHASE3  Change in International Index of Erectile Func...
# 2037  PHASE3  Clinical Benefit Rate (CBR) of tumour response...
# 2062  PHASE3  Pain severity rating scale (FLACC) during inse...
# 2063  PHASE3  Percentage of Participants With Human Immunode...
# 2093  PHASE3  Efficacy:Comparison of 99mTc-EcC-DG SPECT/CT i...
# 2150  PHASE3                                  % Change of LDL-C
# 2409  PHASE3  Proportion of Participants with an Improvement...
# 2796  PHASE3  Immunogenicity of Ad5-nCoV/O or Ad5-nCoV/O-IH ...
# 2856  PHASE3           Systolic Blood Pressure at office (mmHg)
# 2989  PHASE3                                    TCD Measurement
# 3445  PHASE3  Change from baseline in glabella-subnasale-pog...
# 3772  PHASE3  Incidence of adverse events including serious ...

# %%
(43.83 - 30.63) * (5000/30.63)
# Out:
# 2154.750244857982

# %% [markdown]
# dfddsdfddfddfdddff
