# %% [markdown]
# <a href="https://colab.research.google.com/github/Noob1701/Clin_Trials_Clustering/blob/main/Data_Collect2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
import pandas as pd
import requests
import csv

# %%
# Initial URL for the first API call
base_url = "https://clinicaltrials.gov/api/v2/studies"

# Initialize an empty list to store the data
data_list = []
params = {
}

# %%
def write_to_csv(data_list, output_file):
    with open(output_file, 'a', newline='', encoding='utf-8') as f:
        headers = list(data_list[0].keys())
        writer = csv.DictWriter(f, fieldnames=headers)
        # Write headers only if file is empty
        if f.tell() == 0:
            writer.writeheader()

        for data in data_list:
            writer.writerow(data)

# %%
# Loop until there is no nextPageToken
while True:
    # Print the current URL (for debugging purposes)
    # print("Fetching data from:", base_url + '?' + '&'.join([f"{k}={v}" for k, v in params.items()]))

    # Send a GET request to the API
    response = requests.get(base_url, params=params)

    # Check if the request was successful
    if response.status_code == 200:
        data = response.json()  # Parse JSON response
        studies = data.get('studies', [])  # Extract the list of studies

        # Loop through each study and extract specific information
        for study in studies:
            # Safely access nested keys
                responsibleParty = study['protocolSection']['sponsorCollaboratorsModule'].get('responsibleParty', {}).get('type', 'Unknown')
                orgFullName = study['protocolSection']['identificationModule'].get('organization', {}).get('fullName', 'Unknown')
                orgClass = study['protocolSection']['identificationModule'].get('organization',{}).get('class', 'Unknown')
                overallStatus = study['protocolSection']['statusModule'].get('overallStatus', 'Unknown')

                startDate = study['protocolSection']['statusModule'].get('startDateStruct', {}).get('date', 'Unknown')
                if 'conditionsModule' in study['protocolSection']:
                  conditions = ', '.join(study['protocolSection']['conditionsModule'].get('conditions', ['Unknown']))
                else:
                  conditions = 'No conditions listed'
                briefTitle = study['protocolSection']['identificationModule'].get('briefTitle', 'Unknown')
                fullTitle = study['protocolSection']['identificationModule'].get('officialTitle', 'Unknown')
            # Extract interventions safely
                interventions_list = study['protocolSection'].get('armsInterventionsModule', {}).get('interventions', [])
                interventions = ', '.join([intervention.get('name', 'Unknown') for intervention in interventions_list]) if interventions_list else "Unknown"
                interventionDesc_list = study['protocolSection'].get('armsInterventionsModule', {}).get('interventions',[])
                interventionDesc = ', '.join([interventionDesc.get('description', 'Unknown') for interventionDesc in interventionDesc_list]) if interventionDesc_list else "Unknown"

            # Extract dates and phases
                if 'designModule' in study['protocolSection']:
                  studyType = study['protocolSection']['designModule'].get('studyType', 'Unknown')
                else:
                  studyType = 'Unknown'
                if 'designModule' in study['protocolSection']:
                  phases = ', '.join(study['protocolSection']['designModule'].get('phases', ['Unknown']))
                else:
                  phases = 'No phases listed'
                outcome_list = study.get('protocolSection', {}).get('outcomesModule', {}).get('primaryOutcomes', [])
                if outcome_list:
                  outcomes = ' '.join([outcome.get('measure', 'Unknown') for outcome in outcome_list])
                else:
                  outcomes = "Unknown"
                standardAge_list = study['protocolSection'].get('eligibilityModule', {}).get('stdAges',[])
                standardAge = ' '.join(standardAge_list)
                if 'designModule' in study['protocolSection']:
                  if 'designInfo' in study['protocolSection']['designModule']:
                    primaryPurpose = study['protocolSection']['designModule']['designInfo'].get('primaryPurpose', 'Unknown')
                  else:
                    primaryPurpose = 'Unknown'
                else:
                    primaryPurpose = 'Unknown'
                completion_date_list = startDate = study['protocolSection']['statusModule'].get('primaryCompletionDateStruct', {}).get('date', 'Unknown')
            # Append the data to the list as a dictionary
                data_list.append({
                    "Organization Full Name": orgFullName,
                    "Organization Class": orgClass,
                    "Responsible Party": responsibleParty,
                    "Brief Title": briefTitle,
                    "Full Title": fullTitle,
                    "Overall Status": overallStatus,
                    "Start Date": startDate,
                    "Standard Age": standardAge,
                    "Conditions": conditions,
                    "Primary Purpose": primaryPurpose,
                    "Interventions": interventions,
                    "Intervention Description": interventionDesc,
                    "Study Type": studyType,
                    "Phases": phases,
                    "Outcome Measure": outcomes,
                    "Completion Date": completion_date_list
                })

        # Check for nextPageToken and update the params or break the loop
        nextPageToken = data.get('nextPageToken')
        if nextPageToken:
            params['pageToken'] = nextPageToken  # Set the pageToken for the next request
        else:
            break  # Exit the loop if no nextPageToken is present
        if len(data_list) >= 1000:
            write_to_csv(data_list, 'clin_trials.csv')
            data_list = []  # Clear the data list after writing
    else:
        print("Failed to fetch data. Status code:", response.status_code)
        break

# %%
clin_trials = pd.read_csv('clin_trials.csv')

# %%
clin_trials.head(1)
# Out:
#         Organization Full Name Organization Class Responsible Party  \
# 0  University Hospital, Angers          OTHER_GOV           SPONSOR
#
#                                          Brief Title  \
# 0  Reproducibility of Ankle Brachial Index After ...
#
#                                           Full Title Overall Status  \
# 0  Reproducibility of the Ankle-Brachial Index Me...      COMPLETED
#
#   Start Date Standard Age       Conditions Primary Purpose Interventions  \
# 0    2014-04        ADULT  Normal Subjects         Unknown       Unknown
#
#   Intervention Description     Study Type   Phases  \
# 0                  Unknown  OBSERVATIONAL  Unknown
#
#                                      Outcome Measure Completion Date
# 0  Test-retest difference in ankle to brachial pr...         2014-04

# %%
clin_trials = clin_trials.sort_values(by= 'Completion Date', ascending=False)

# %%
clin_trials.head(20)
# Out:
#                                    Organization Full Name Organization Class  \
# 70265                         Thomas Jefferson University              OTHER
# 40472                                     GlaxoSmithKline           INDUSTRY
# 362942        Weill Medical College of Cornell University              OTHER
# 155975  National Institutes of Health Clinical Center ...                NIH
# 416175                              University of Chicago              OTHER
# 201340                                         [Redacted]            Unknown
# 115237  National Institute of Allergy and Infectious D...                NIH
# 424446  National Institutes of Health Clinical Center ...                NIH
# 201347                                         [Redacted]            Unknown
# 201350                                        Mayo Clinic              OTHER
# 115253  National Institutes of Health Clinical Center ...                NIH
# 40484                         University of South Florida              OTHER
# 201356                                             Sanofi           INDUSTRY
# 115265                        City of Hope Medical Center              OTHER
# 40477                      Cleveland Chiropractic College              OTHER
# 362980                   Tibotec Pharmaceuticals, Ireland           INDUSTRY
# 362982                 Pro Top & Mediking Company Limited           INDUSTRY
# 115226   Association Européenne de Recherche en Oncologie              OTHER
# 401049                National Taiwan University Hospital              OTHER
# 445440                                         [Redacted]            Unknown
#
#              Responsible Party  \
# 70265                  SPONSOR
# 40472                  SPONSOR
# 362942                 SPONSOR
# 155975                 Unknown
# 416175                 SPONSOR
# 201340                 Unknown
# 115237                 SPONSOR
# 424446                 Unknown
# 201347                 Unknown
# 201350  PRINCIPAL_INVESTIGATOR
# 115253                 Unknown
# 40484   PRINCIPAL_INVESTIGATOR
# 201356                 Unknown
# 115265                 Unknown
# 40477                  Unknown
# 362980                 SPONSOR
# 362982                 Unknown
# 115226                 Unknown
# 401049                 Unknown
# 445440                 Unknown
#
#                                               Brief Title  \
# 70265   Comparison of Tissue Retractors During Cesarea...
# 40472   Topical GW842470X In Adults Patients With Mode...
# 362942  Intra Ocular Pressure During Robotic Prostatec...
# 155975             Mechanisms of Lung Allograft Rejection
# 416175  Evaluation of Lovastatin in Severe Persistent ...
# 201340  [Trial of device that is not approved or clear...
# 115237  A Phase I Multicenter Clinical Trial to Evalua...
# 424446                          Brain Encoding for Memory
# 201347  [Trial of device that is not approved or clear...
# 201350  Clinical Use of a Magnetic Anal Sphincter Augm...
# 115253  Determination of Variances in Exhaled Nitric O...
# 40484     Assessing Outcome After H-graft Shunt Placement
# 201356  A Phase II Study of Oxaliplatin in Association...
# 115265  SU5416 and Paclitaxel in Treating Patients Wit...
# 40477   Feasibility Study of Short-Term Effects of Chi...
# 362980  TMC435-TiDP16-C115 - A Study in Healthy Volunt...
# 362982  Ologen (OculusGen)-Glaucoma and Pterygium Hist...
# 115226  5FU/VL Vs LV5FU2 + CPT11 in Stage II-III Resec...
# 401049  Sublingual Immunotherapy With House Dust Mite ...
# 445440  [Trial of device that is not approved or clear...
#
#                                                Full Title  \
# 70265   Randomized Controlled Trial of the Efficacy of...
# 40472   Randomised, Double-blind, Placebo-controlled S...
# 362942  Intra Ocular Pressure During Robotic Prostatec...
# 155975             Mechanisms of Lung Allograft Rejection
# 416175  Evaluation of Lovastatin in Severe Persistent ...
# 201340  [Trial of device that is not approved or clear...
# 115237  A Phase I Multicenter Clinical Trial to Evalua...
# 424446  Role of the Prefrontal Cortex in Successful Me...
# 201347  [Trial of device that is not approved or clear...
# 201350  Clinical Use of a Magnetic Anal Sphincter Augm...
# 115253  The Determination of Variances in Exhaled Nitr...
# 40484   A Study Assessing Patient Outcomes After Place...
# 201356  A Phase II Study of Oxaliplatin in Association...
# 115265  Phase I Trial of SU5416 in Combination With We...
# 40477   Feasibility Study of Short-Term Effects of Chi...
# 362980  A Phase I, 2-panel, Open-label, Randomized, Cr...
# 362982  Study of the Safety and Effectiveness of the O...
# 115226                                            Unknown
# 401049  Efficacy and Safety of Sublingual Immunotherap...
# 445440  [Trial of device that is not approved or clear...
#
#              Overall Status Start Date             Standard Age  \
# 70265               UNKNOWN    Unknown  CHILD ADULT OLDER_ADULT
# 40472             COMPLETED    Unknown        ADULT OLDER_ADULT
# 362942            COMPLETED    Unknown        ADULT OLDER_ADULT
# 155975            COMPLETED    Unknown        ADULT OLDER_ADULT
# 416175            WITHDRAWN    Unknown        ADULT OLDER_ADULT
# 201340             WITHHELD    Unknown                      NaN
# 115237            COMPLETED    Unknown                    ADULT
# 424446            COMPLETED    Unknown  CHILD ADULT OLDER_ADULT
# 201347             WITHHELD    Unknown                      NaN
# 201350  NO_LONGER_AVAILABLE    Unknown        ADULT OLDER_ADULT
# 115253            COMPLETED    Unknown  CHILD ADULT OLDER_ADULT
# 40484             COMPLETED    Unknown        ADULT OLDER_ADULT
# 201356            COMPLETED    Unknown        ADULT OLDER_ADULT
# 115265            COMPLETED    Unknown        ADULT OLDER_ADULT
# 40477             COMPLETED    Unknown              OLDER_ADULT
# 362980            COMPLETED    Unknown                    ADULT
# 362982            COMPLETED    Unknown        ADULT OLDER_ADULT
# 115226              UNKNOWN    Unknown        ADULT OLDER_ADULT
# 401049              UNKNOWN    Unknown                    CHILD
# 445440             WITHHELD    Unknown                      NaN
#
#                                                Conditions Primary Purpose  \
# 70265                           Cesarean Section, Obesity       TREATMENT
# 40472               Atopic Dermatitis, Dermatitis, Atopic       TREATMENT
# 362942  Visual Acuity, Visual Disturbance, Intraocular...         Unknown
# 155975       Lung Transplant, Chronic Allograft Rejection         Unknown
# 416175                           Severe Persistent Asthma       TREATMENT
# 201340                               No conditions listed         Unknown
# 115237                                     HIV Infections      PREVENTION
# 424446                                            Healthy         Unknown
# 201347                               No conditions listed         Unknown
# 201350                                 Fecal Incontinence         Unknown
# 115253                                            Healthy         Unknown
# 40484                                 Portal Hypertension         Unknown
# 201356                                  Stomach Neoplasms       TREATMENT
# 115265   Unspecified Adult Solid Tumor, Protocol Specific       TREATMENT
# 40477                         Musculoskeletal Equilibrium      PREVENTION
# 362980                                  Hepatitis C Virus       TREATMENT
# 362982                               Glaucomas, Pterygium       TREATMENT
# 115226                               Cancer of the Rectum       TREATMENT
# 401049                                             Asthma       TREATMENT
# 445440                               No conditions listed         Unknown
#
#                                             Interventions  \
# 70265   Mobius™ retractor, traditional metal retractio...
# 40472                                     GW842470X cream
# 362942                                            Unknown
# 155975                                            Unknown
# 416175                                Lovastatin, Placebo
# 201340                                            Unknown
# 115237                          gp160 Vaccine (Immuno-AG)
# 424446                  Magstim Rapid Magnetic Stimulator
# 201347                                            Unknown
# 201350  magnetic anal sphincter augmentation for fecal...
# 115253                                            Unknown
# 40484                                        Chart Review
# 201356                        Oxaliplatin, 5-Fluorouracil
# 115265                              paclitaxel, semaxanib
# 40477                           Chiropractic manipulation
# 362980  erythromycin, Ritonavir, TMC435, Darunavir, TM...
# 362982    OculusGen Biodegradable Collagen Matrix Implant
# 115226  5FU/LV Mayo Clinic or LV5FU2, LV5FU2 + irinotecan
# 401049                                        Staloral TM
# 445440                                            Unknown
#
#                                  Intervention Description       Study Type  \
# 70265                                    Unknown, Unknown   INTERVENTIONAL
# 40472                                             Unknown   INTERVENTIONAL
# 362942                                            Unknown    OBSERVATIONAL
# 155975                                            Unknown    OBSERVATIONAL
# 416175  Lovastatin 20 mg extended release (or placebo)...   INTERVENTIONAL
# 201340                                            Unknown          Unknown
# 115237                                            Unknown   INTERVENTIONAL
# 424446                                            Unknown    OBSERVATIONAL
# 201347                                            Unknown          Unknown
# 201350  Surgical placement of HUD called FENIX for fem...  EXPANDED_ACCESS
# 115253                                            Unknown    OBSERVATIONAL
# 40484   Patients' charts will be reviewed for relevant...    OBSERVATIONAL
# 201356  5FU 500 mg/m² per week in IV bolus infusion du...   INTERVENTIONAL
# 115265                                   Unknown, Unknown   INTERVENTIONAL
# 40477                                             Unknown   INTERVENTIONAL
# 362980  500 mg tablets three times a day for 6 days + ...   INTERVENTIONAL
# 362982                                            Unknown   INTERVENTIONAL
# 115226                                   Unknown, Unknown   INTERVENTIONAL
# 401049                                            Unknown   INTERVENTIONAL
# 445440                                            Unknown          Unknown
#
#                   Phases                                    Outcome Measure  \
# 70265                NaN                                     operative time
# 40472             PHASE2  Clinical efficacy of 3% GW842470X cream applie...
# 362942           Unknown                                            Unknown
# 155975           Unknown                                            Unknown
# 416175    PHASE1, PHASE2  Changes in airway smooth muscle biology and in...
# 201340  No phases listed                                            Unknown
# 115237            PHASE1                                            Unknown
# 424446           Unknown                                            Unknown
# 201347  No phases listed                                            Unknown
# 201350           Unknown                                            Unknown
# 115253           Unknown                                            Unknown
# 40484            Unknown  The objective of this study is to evaluate the...
# 201356            PHASE2   Response rate - RECIST criteria (unidimensional)
# 115265            PHASE1                                            Unknown
# 40477                NaN  Specific Aim 1: Recruitment Tracking Completen...
# 362980            PHASE1  Change in the steady-state plasma pharmacokine...
# 362982            PHASE3  the effectiveness via the reduction of IOP and...
# 115226            PHASE3                                            Unknown
# 401049            PHASE4           Change of asthmatic scores from baseline
# 445440  No phases listed                                            Unknown
#
#        Completion Date
# 70265          Unknown
# 40472          Unknown
# 362942         Unknown
# 155975         Unknown
# 416175         Unknown
# 201340         Unknown
# 115237         Unknown
# 424446         Unknown
# 201347         Unknown
# 201350         Unknown
# 115253         Unknown
# 40484          Unknown
# 201356         Unknown
# 115265         Unknown
# 40477          Unknown
# 362980         Unknown
# 362982         Unknown
# 115226         Unknown
# 401049         Unknown
# 445440         Unknown

# %%
clin_trials_wd = clin_trials[clin_trials['Completion Date'] != 'Unknown']

# %%
clin_trials_wd.head(20)
# Out:
#                           Organization Full Name Organization Class  \
# 71453          University of Southern California              OTHER
# 281717                                 CorEvitas            NETWORK
# 50480                             Sanford Health              OTHER
# 285370                                 CorEvitas            NETWORK
# 413110                                 CorEvitas            NETWORK
# 51114                                  CorEvitas            NETWORK
# 401909                                 CorEvitas            NETWORK
# 164394                                 CorEvitas            NETWORK
# 121912       Maccabi Healthcare Services, Israel              OTHER
# 447247                                 CorEvitas            NETWORK
# 441937       Maccabi Healthcare Services, Israel              OTHER
# 469740                                 CorEvitas            NETWORK
# 413449                 Children's Oncology Group            NETWORK
# 107779                 Children's Oncology Group            NETWORK
# 151752                 Children's Oncology Group            NETWORK
# 409302           National Cancer Institute (NCI)                NIH
# 52309            North Carolina State University              OTHER
# 360876           National Cancer Institute (NCI)                NIH
# 377326           National Cancer Institute (NCI)                NIH
# 197584  Alliance for Clinical Trials in Oncology              OTHER
#
#              Responsible Party  \
# 71453   PRINCIPAL_INVESTIGATOR
# 281717                 SPONSOR
# 50480                  SPONSOR
# 285370                 SPONSOR
# 413110                 SPONSOR
# 51114                  SPONSOR
# 401909                 SPONSOR
# 164394                 SPONSOR
# 121912                 SPONSOR
# 447247                 SPONSOR
# 441937                 SPONSOR
# 469740                 SPONSOR
# 413449                 SPONSOR
# 107779                 SPONSOR
# 151752                 SPONSOR
# 409302                 SPONSOR
# 52309   PRINCIPAL_INVESTIGATOR
# 360876                 SPONSOR
# 377326                 SPONSOR
# 197584                 SPONSOR
#
#                                               Brief Title  \
# 71453   PPI Versus Placebo in Severe Functional Heartburn
# 281717  Corrona Atopic Dermatitis Registry: A Study of...
# 50480   Rare Disease Patient Registry & Natural Histor...
# 285370                         Rheumatology Biorepository
# 413110  Corrona Inflammatory Bowel Disease (IBD) Registry
# 51114   The Corrona Psoriatic Arthritis and Spondyloar...
# 401909               The Corrona Psoriasis (PSO) Registry
# 164394  CorEvitas Japan Rheumatoid Arthritis (RA) Regi...
# 121912        Registry of Cardiovascular Disease Patients
# 447247         Corevitas Multiple Sclerosis (MS) Registry
# 441937  Registry of Diabetes Patients in a Large Healt...
# 469740  Corrona Rheumatoid Arthritis (RA) Drug Safety ...
# 413449  Long-Term Follow-Up of Patients Who Have Parti...
# 107779         Study of Kidney Tumors in Younger Patients
# 151752  Biomarkers in Tumor Tissue Samples From Patien...
# 409302  Whole Exome Sequencing in Finding Causative Va...
# 52309   Analysis and Suppression of Tremor During Gras...
# 360876  Whole Exome Sequencing in Finding Causative Va...
# 377326  Whole Exome Sequencing in Finding Causative Va...
# 197584  Multidrug Resistance Genes in Patients With Ac...
#
#                                                Full Title  \
# 71453   PPI Versus Placebo in Severe Functional Heartburn
# 281717  Corrona Atopic Dermatitis Registry: A Study of...
# 50480            Coordination of Rare Diseases at Sanford
# 285370                         Rheumatology Biorepository
# 413110  Corrona Inflammatory Bowel Disease (IBD) Registry
# 51114   Corrona Psoriatic Arthritis and Spondyloarthri...
# 401909                   Corrona Psoriasis (PSO) Registry
# 164394  CorEvitas Japan Rheumatoid Arthritis (RA) Regi...
# 121912  Computerized Registry of Cardiovascular Diseas...
# 447247         CorEvitas Multiple Sclerosis (MS) Registry
# 441937  Computerized Registry of Diabetes Patients in ...
# 469740  Corrona Rheumatoid Arthritis (RA) Drug Safety ...
# 413449              Umbrella Long-Term Follow-Up Protocol
# 107779  Renal Tumors Classification, Biology, and Bank...
# 151752                      Neuroblastoma Biology Studies
# 409302  Exploratory Next Generation Sequencing to Iden...
# 52309   Analysis and Suppression of Tremor During Gras...
# 360876  Exploratory Next Generation Sequencing to Iden...
# 377326  Exploratory Next Generation Sequencing to Iden...
# 197584  Multidrug Resistance Protein Gene Polymorphism...
#
#                  Overall Status  Start Date             Standard Age  \
# 71453                 WITHDRAWN  2100-12-01        ADULT OLDER_ADULT
# 281717  ENROLLING_BY_INVITATION     2100-12        ADULT OLDER_ADULT
# 50480                RECRUITING     2100-12  CHILD ADULT OLDER_ADULT
# 285370  ENROLLING_BY_INVITATION     2100-12        ADULT OLDER_ADULT
# 413110  ENROLLING_BY_INVITATION     2100-12        ADULT OLDER_ADULT
# 51114   ENROLLING_BY_INVITATION     2100-12        ADULT OLDER_ADULT
# 401909  ENROLLING_BY_INVITATION     2100-12        ADULT OLDER_ADULT
# 164394  ENROLLING_BY_INVITATION     2100-12        ADULT OLDER_ADULT
# 121912  ENROLLING_BY_INVITATION     2100-12  CHILD ADULT OLDER_ADULT
# 447247  ENROLLING_BY_INVITATION     2100-12        ADULT OLDER_ADULT
# 469740                                            Unknown   OBSERVATIONAL
# 413449  Complete patient response form and Health Stat...   OBSERVATIONAL
# 107779           Correlative studies, Correlative studies   OBSERVATIONAL
# 151752           Correlative studies, Correlative studies   OBSERVATIONAL
# 409302                                Correlative studies   OBSERVATIONAL
# 52309   We will collect ultrasound images during the g...  INTERVENTIONAL
# 360876                                Correlative studies   OBSERVATIONAL
# 377326                                Correlative studies   OBSERVATIONAL
# 197584        Unknown, Unknown, Unknown, Unknown, Unknown   OBSERVATIONAL
#
#          Phases                                    Outcome Measure  \
# 71453       NaN  Difference in GERD controll PPI vs Placebo bas...
# 281717  Unknown  AD epidemiology, presentation, natural history...
# 50480   Unknown  To accelerate research into rare disorders by ...
# 285370  Unknown  1. Biospecimen (blood) Collection 2. Laborator...
# 413110  Unknown  IBD epidemiology, presentation, natural histor...
# 51114   Unknown  The major clinical outcomes include an assessm...
# 401909  Unknown  Number of patients with adverse events (AEs) o...
# 164394  Unknown  Incidence rate of adverse events (AEs) will be...
# 121912  Unknown     Number of Patients with Cardiovascular disease
# 447247  Unknown  Number of patients with adverse events (AEs) o...
# 441937  Unknown                       Prevalence rates of Diabetes
# 469740  Unknown  Patterns, effectiveness, and safety of DMARDs,...
# 413449  Unknown  Percentage of patients enrolled Percentage of ...
# 107779  Unknown               Event-free survival Overall survival
# 151752  Unknown  Factors currently used for risk-group assignme...
# 409302  Unknown  Identification of rare coding variants of larg...
# 52309       NaN  Tremor Model Ultrasound Imaging Based Frequenc...
# 360876  Unknown  Identification of rare coding variants of larg...
# 377326  Unknown  Identification of rare coding variants of larg...
# 197584  Unknown  Correlation of common single nucleotide polymo...
#
#        Completion Date
# 71453       2100-12-01
# 281717         2100-12
# 50480          2100-12
# 285370         2100-12
# 413110         2100-12
# 51114          2100-12
# 401909         2100-12
# 164394         2100-12
# 121912         2100-12
# 447247         2100-12
# 441937         2100-12
# 469740         2100-12
# 413449      2100-01-31
# 107779      2100-01-01
# 151752      2100-01-01
# 409302      2100-01-01
# 52309       2100-01-01
# 360876      2100-01-01
# 377326      2100-01-01
# 197584         2100-01

# %%
clin_trials_wd = clin_trials_wd[clin_trials_wd['Completion Date'] < '2024-07-05']

# %%
clin_trials_wd.head(20)
# Out:
#                            Organization Full Name Organization Class  \
# 390439                                   Novartis           INDUSTRY
# 355694                       Hacettepe University              OTHER
# 131455                                Mayo Clinic              OTHER
# 247391                    Sawanpracharak hospital              OTHER
# 92512                         Mansoura University              OTHER
# 417962                       Boehringer Ingelheim           INDUSTRY
# 286826    Assistance Publique - Hôpitaux de Paris              OTHER
# 413926                                    vandfys              OTHER
# 458438            Central Hospital, Nancy, France              OTHER
# 107011                       Hacettepe University              OTHER
# 142576                        Menoufia University              OTHER
# 238518                       Sheba Medical Center          OTHER_GOV
# 224856                            GlaxoSmithKline           INDUSTRY
# 495442  Insel Gruppe AG, University Hospital Bern              OTHER
# 429613                               CHU de Reims              OTHER
# 212410  Investigación en Hemofilia y Fisioterapia            NETWORK
# 459837                    University of Ljubljana              OTHER
# 459883          Universidade Estadual de Londrina              OTHER
# 429613                                        Data record
# 212410                             Blood flow restriction
# 459837                           Zirconia dental implants
# 459883                         Dry Needling, Lasertherapy
# 413392                     JNJ-75229414, Bridging Therapy
# 88018                               L-Citrulline, capsule
#
#                                  Intervention Description      Study Type  \
# 390439  Sabatolimab is a solution in vial for IV infus...  INTERVENTIONAL
# 355694  Schroth exercises are including rotational bre...  INTERVENTIONAL
# 131455  Mock consent form with consistent content in a...  INTERVENTIONAL
# 247391  Pharyngeal anesthesia using a topical lidocain...  INTERVENTIONAL
# 92512   Evaluation of patient satisfaction and oral he...  INTERVENTIONAL
# 417962                                BI 1569912, Placebo  INTERVENTIONAL
# 286826  Drink caffeinated coffee one morning and drink...  INTERVENTIONAL
# 413926                Aquatic physiotherapy in warm water  INTERVENTIONAL
# 458438                                            Unknown   OBSERVATIONAL
# 107011  Lateralization Training: Individuals with cerv...  INTERVENTIONAL
# 142576  Denture base material constructed with differe...   OBSERVATIONAL
# 238518  fourth dose of the mRNA1273 vaccine (50 microg...  INTERVENTIONAL
# 224856  GSK2556286 will be administered., Placebo will...  INTERVENTIONAL
# 495442  Minimal invasive Urodynamic examination: Cysto...   OBSERVATIONAL
# 429613  characteristics of patients, initial clinical ...   OBSERVATIONAL
# 212410  The intervention protocol through blood flow r...  INTERVENTIONAL
# 459837  Dental implants produced from zirconia materia...  INTERVENTIONAL
# 459883  Dry Needling: The technique will be used by a ...  INTERVENTIONAL
# 413392  JNJ-75229414 infusion will be administered int...  INTERVENTIONAL
# 88018   5g/daily dose for the duration of 1 week inter...  INTERVENTIONAL
#
#                 Phases                                    Outcome Measure  \
# 390439  PHASE1, PHASE2  Incidence of dose limiting toxicities (Safety ...
# 355694             NaN           Trunk rotation Cobb angles Serum markers
# 131455             NaN                                 Decision to enroll
# 247391             NaN  procedural pain, measured using the visual ana...
# 92512              NaN                               Patient satisfaction
# 417962          PHASE1  Percentage of subjects with drug-related adver...
# 286826             NaN                  Quantification movement disorders
# 413926             NaN                          Level of symptoms of PTSD
# 458438         Unknown  relative change in FVC after 12 months of JAK ...
# 107011             NaN  Evaluation of Normal Joint Range of Motion Eva...
# 142576         Unknown                                  Biofilm formation
# 238518          PHASE3  Geometric mean of antibody titers of each arm,...
# 224856          PHASE1  Part A: Number of participants with any seriou...
# 495442         Unknown  Number of voids per 24 hours Number of leakage...
# 429613         Unknown                                              Death
# 212410             NaN  Change from baseline hemarthrosis after treatm...
# 459837             NaN                             Crestal bone loss (mm)
# 459883             NaN                           change in pain intensity
# 413392          PHASE1  Number of Participants With Adverse Events (AE...
# 88018           PHASE1  Change in neurovascular coupling using functio...
#
#        Completion Date
# 390439      2024-07-04
# 355694      2024-07-04
# 131455      2024-07-04
# 247391      2024-07-04
# 92512       2024-07-04
# 417962      2024-07-04
# 286826      2024-07-04
# 413926      2024-07-04
# 458438      2024-07-04
# 107011      2024-07-04
# 142576      2024-07-04
# 238518      2024-07-04
# 224856      2024-07-04
# 495442      2024-07-03
# 429613      2024-07-03
# 212410      2024-07-03
# 459837      2024-07-03
# 459883      2024-07-03
# 413392      2024-07-03
# 88018       2024-07-03
