# %% [markdown]
# <a href="https://colab.research.google.com/github/Noob1701/Clin_Trials_Clustering/blob/main/Data_Collect2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
import pandas as pd
import requests
import csv

# %%
# Initial URL for the first API call
base_url = "https://clinicaltrials.gov/api/v2/studies"

# Initialize an empty list to store the data
data_list = []
params = {
}

# %%
def write_to_csv(data_list, output_file):
    with open(output_file, 'a', newline='', encoding='utf-8') as f:
        headers = list(data_list[0].keys())
        writer = csv.DictWriter(f, fieldnames=headers)
        # Write headers only if file is empty
        if f.tell() == 0:
            writer.writeheader()

        for data in data_list:
            writer.writerow(data)

# %%
# Loop until there is no nextPageToken
while True:
    # Print the current URL (for debugging purposes)
    # print("Fetching data from:", base_url + '?' + '&'.join([f"{k}={v}" for k, v in params.items()]))

    # Send a GET request to the API
    response = requests.get(base_url, params=params)

    # Check if the request was successful
    if response.status_code == 200:
        data = response.json()  # Parse JSON response
        studies = data.get('studies', [])  # Extract the list of studies

        # Loop through each study and extract specific information
        for study in studies:
            # Safely access nested keys
                responsibleParty = study['protocolSection']['sponsorCollaboratorsModule'].get('responsibleParty', {}).get('type', 'Unknown')
                orgFullName = study['protocolSection']['identificationModule'].get('organization', {}).get('fullName', 'Unknown')
                orgClass = study['protocolSection']['identificationModule'].get('organization',{}).get('class', 'Unknown')
                overallStatus = study['protocolSection']['statusModule'].get('overallStatus', 'Unknown')

                startDate = study['protocolSection']['statusModule'].get('startDateStruct', {}).get('date', 'Unknown')
                if 'conditionsModule' in study['protocolSection']:
                  conditions = ', '.join(study['protocolSection']['conditionsModule'].get('conditions', ['Unknown']))
                else:
                  conditions = 'No conditions listed'
                briefTitle = study['protocolSection']['identificationModule'].get('briefTitle', 'Unknown')
                fullTitle = study['protocolSection']['identificationModule'].get('officialTitle', 'Unknown')
            # Extract interventions safely
                interventions_list = study['protocolSection'].get('armsInterventionsModule', {}).get('interventions', [])
                interventions = ', '.join([intervention.get('name', 'Unknown') for intervention in interventions_list]) if interventions_list else "Unknown"
                interventionDesc_list = study['protocolSection'].get('armsInterventionsModule', {}).get('interventions',[])
                interventionDesc = ', '.join([interventionDesc.get('description', 'Unknown') for interventionDesc in interventionDesc_list]) if interventionDesc_list else "Unknown"

            # Extract dates and phases
                if 'designModule' in study['protocolSection']:
                  studyType = study['protocolSection']['designModule'].get('studyType', 'Unknown')
                else:
                  studyType = 'Unknown'
                if 'designModule' in study['protocolSection']:
                  phases = ', '.join(study['protocolSection']['designModule'].get('phases', ['Unknown']))
                else:
                  phases = 'No phases listed'
                outcome_list = study.get('protocolSection', {}).get('outcomesModule', {}).get('primaryOutcomes', [])
                if outcome_list:
                  outcomes = ' '.join([outcome.get('measure', 'Unknown') for outcome in outcome_list])
                else:
                  outcomes = "Unknown"
                standardAge_list = study['protocolSection'].get('eligibilityModule', {}).get('stdAges',[])
                standardAge = ' '.join(standardAge_list)
                if 'designModule' in study['protocolSection']:
                  if 'designInfo' in study['protocolSection']['designModule']:
                    primaryPurpose = study['protocolSection']['designModule']['designInfo'].get('primaryPurpose', 'Unknown')
                  else:
                    primaryPurpose = 'Unknown'
                else:
                    primaryPurpose = 'Unknown'
                completion_date_list = study['protocolSection']['statusModule'].get('primaryCompletionDateStruct', {}).get('date', 'Unknown')
            # Append the data to the list as a dictionary
                data_list.append({
                    "Organization Full Name": orgFullName,
                    "Organization Class": orgClass,
                    "Responsible Party": responsibleParty,
                    "Brief Title": briefTitle,
                    "Full Title": fullTitle,
                    "Overall Status": overallStatus,
                    "Start Date": startDate,
                    "Standard Age": standardAge,
                    "Conditions": conditions,
                    "Primary Purpose": primaryPurpose,
                    "Interventions": interventions,
                    "Intervention Description": interventionDesc,
                    "Study Type": studyType,
                    "Phases": phases,
                    "Outcome Measure": outcomes,
                    "Completion Date": completion_date_list
                })

        # Check for nextPageToken and update the params or break the loop
        nextPageToken = data.get('nextPageToken')
        if nextPageToken:
            params['pageToken'] = nextPageToken  # Set the pageToken for the next request
        else:
            break  # Exit the loop if no nextPageToken is present
        if len(data_list) >= 1000:
            write_to_csv(data_list, 'clin_trials.csv')
            data_list = []  # Clear the data list after writing
    else:
        print("Failed to fetch data. Status code:", response.status_code)
        break

# %%
clin_trials = pd.read_csv('clin_trials.csv')

# %%
clin_trials.head(1)
# Out:
#         Organization Full Name Organization Class Responsible Party  \
# 0  University Hospital, Angers          OTHER_GOV           SPONSOR
#
#                                          Brief Title  \
# 0  Reproducibility of Ankle Brachial Index After ...
#
#                                           Full Title Overall Status  \
# 0  Reproducibility of the Ankle-Brachial Index Me...      COMPLETED
#
#   Start Date Standard Age       Conditions Primary Purpose Interventions  \
# 0    2012-11        ADULT  Normal Subjects         Unknown       Unknown
#
#   Intervention Description     Study Type   Phases  \
# 0                  Unknown  OBSERVATIONAL  Unknown
#
#                                      Outcome Measure Completion Date
# 0  Test-retest difference in ankle to brachial pr...         2014-04

# %%
clin_trials_wd = clin_trials[clin_trials['Completion Date'] != 'Unknown']

# %%
clin_trials_wd = clin_trials_wd[clin_trials_wd['Responsible Party'] == 'SPONSOR']

# %%
clin_trials_wd = clin_trials_wd[clin_trials_wd['Organization Class'] == 'INDUSTRY']

# %%
clin_trials_wd = clin_trials_wd[(clin_trials_wd['Completion Date'] < '2024-07-05') & (clin_trials_wd['Completion Date'] > '2022-01-01')]

# %%
clin_trials_wd = clin_trials_wd[clin_trials_wd['Phases'] == 'PHASE3']

# %%
column_to_move = 'Completion Date'
cols = [column_to_move] + [col for col in clin_trials_wd.columns if col != column_to_move]
clin_trials_wd = clin_trials_wd[cols]

# %%
clin_trials_wd = clin_trials_wd.sort_values(by='Completion Date', ascending=False)

# %%
clin_trials_wd.head(20)
# Out:
#        Completion Date         Organization Full Name Organization Class  \
# 186505      2024-07-02                    AstraZeneca           INDUSTRY
# 335675      2024-07-02                    AstraZeneca           INDUSTRY
# 445091      2024-07-01                     FutureChem           INDUSTRY
# 493449      2024-07-01        Alume Biosciences, Inc.           INDUSTRY
# 34064       2024-07-01                    GIE Medical           INDUSTRY
# 46044       2024-07-01                     Lupin Ltd.           INDUSTRY
# 231804         2024-07     AMAG Pharmaceuticals, Inc.           INDUSTRY
# 182054         2024-07    Ionis Pharmaceuticals, Inc.           INDUSTRY
# 220763         2024-07                  ACELYRIN Inc.           INDUSTRY
# 453973         2024-07  Everstar Therapeutics Limited           INDUSTRY
# 92733          2024-07    Boryung Biopharma Co., Ltd.           INDUSTRY
# 481943                                        Savolitinib
# 42759                                Tirzepatide, Placebo
# 286910  Hepatitis B vaccine lot 1, Hepatitis B vaccine...
# 169506                          Itolizumab, EQ001 Placebo
# 87905                              Atenas, Atenas placebo
# 168569                     D-PLEX, Standard of Care (SoC)
#
#                                  Intervention Description      Study Type  \
# 186505  * Dose formulation: MDI\n* Unit dose strength(...  INTERVENTIONAL
# 335675  Olaparib tablets 300 mg oral twice daily, Matc...  INTERVENTIONAL
# 445091  A single dose of \[F-18\]Florastamin at 10 ± 1...  INTERVENTIONAL
# 493449  ALM-488 will be infused during the pre-operati...  INTERVENTIONAL
# 34064   Paclitaxel Coated Balloon, Standard Endoscopic...  INTERVENTIONAL
# 46044   Mexiletine 167 mg (equivalent to mexiletine HC...  INTERVENTIONAL
# 231804  Each 20 mL single-use vial contains 17 mL of f...  INTERVENTIONAL
# 182054  Eplontersen will be administered by SC injection.  INTERVENTIONAL
# 220763     Solution for injection, Solution for injection  INTERVENTIONAL
# 453973  Drug:Etrasimod Tablet other name:APD334, Drug:...  INTERVENTIONAL
# 92733   Dosage and administration: pre-iflled syringe,...  INTERVENTIONAL
# 243930  The StimRelieve Halo System is intended as the...  INTERVENTIONAL
# 344832  Suspension of inert, crystalline hafnium oxide...  INTERVENTIONAL
# 16555                                  Twice daily dosing  INTERVENTIONAL
# 481943  Patients meeting the study inclusion criteria ...  INTERVENTIONAL
# 42759   Administered SC as add-on to the pre-trial bac...  INTERVENTIONAL
# 286910  3 doses of Hepatitis B vaccine lot 1, 3 doses ...  INTERVENTIONAL
# 169506              Itolizumab \[Bmab600\], EQ001 Placebo  INTERVENTIONAL
# 87905   ATENAS 1 coated tablet, once a day EMPAGLIFLOZ...  INTERVENTIONAL
# 168569  D-PLEX is a new formulation of extended releas...  INTERVENTIONAL
#
#         Phases                                    Outcome Measure
# 186505  PHASE3  Change from baseline in MCC through 60 minutes...
# 335675  PHASE3  Superiority of olaparib as maintenance treatme...
# 445091  PHASE3  Diagnostic sensitivity and specificity analyze...
# 493449  PHASE3            Contrast Enhancement Length Measurement
# 34064   PHASE3           Treatment Success Primary Safety Outcome
# 46044   PHASE3  Assess the efficacy and safety of mexiletine f...
# 231804  PHASE3       Change in Hemoglobin from Baseline to Week 5
# 182054  PHASE3  Change From Baseline in Platelet Count Number ...
# 220763  PHASE3       Percentage of Participants Achieving HiSCR75
# 453973  PHASE3  Proportion of Subjects With Clinical Remission...
# 92733   PHASE3  Anti-HAV seroconversion rate at 4 weeks after ...
# 243930  PHASE3                       Headache Days Adverse Events
# 344832  PHASE3                    Progression-free Survival (PFS)
# 16555   PHASE3  Number of Participants with Adverse Events as ...
# 481943  PHASE3  Objective response rate (ORR) evaluated by the...
# 42759   PHASE3  Mean Change from Baseline in HbA1c (Tirzepatid...
# 286910  PHASE3  Percentage of subjects with increasing antibod...
# 169506  PHASE3  The efficacy of itolizumab versus placebo as i...
# 87905   PHASE3  Glycated hemoglobin Systolic blood pressure (SBP)
# 168569  PHASE3  To assess the anti-infective efficacy of D-PLE...

# %%
(43.83 - 30.63) * (5000/30.63)
# Out:
# 2154.750244857982

# %% [markdown]
# dfddsdfddfddfdddff
